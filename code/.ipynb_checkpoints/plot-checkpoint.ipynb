# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable


def plot_N(images, texts=None, cmap=None):
    
    fig = plt.figure(figsize=(32, 10))
    gs = GridSpec(nrows=1, ncols=len(images))
    gs.update( hspace = 0.5, wspace = 0.)

    for i in range(len(images)):
        ax = fig.add_subplot(gs[0, i])
        
        if cmap is None:
            im = ax.imshow(images[i], vmin=0, vmax=1)
        else:
            im = ax.imshow(images[i], vmin=0, vmax=1, cmap=cmap)
        
        ax.patch.set_edgecolor('white')  
        ax.patch.set_linewidth(5) 
        ax.set_xticks([])
        ax.set_yticks([])
        
        if texts is not None:
            ax.text(15, -5,  texts[i], size=15, ha="center", color='black') #128
        
    plt.show()

# %%
f = np.load('mnist_adam87_tf.pth_moving_mnist_prediction.npz')
ground_truth = f['ground_truth']
prediction = f['prediction']


for sample_id in range(0, 10):
    
    print(f'This is sample {sample_id}. ')
    
    gt_frames, pred_frames = [], []
    for i in range(ground_truth.shape[1]):
        gt_i = ground_truth[sample_id, i, 0, ...]
        gt_frames.append(gt_i)
        
        pred_i = prediction[sample_id, i, 0, ...]
        pred_frames.append(pred_i)
    plot_N(gt_frames)            
    plot_N(pred_frames)
# Out:
# This is sample 0.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8b959e0e017d> in <module>
#      15         pred_i = prediction[sample_id, i, 0, ...]
#      16         pred_frames.append(pred_i)
# ---> 17     print(gt_frames.shape)
#      18     plot_N(gt_frames)
#      19     plot_N(pred_frames)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
for sample_id in range(0, 10):
    
    print(f'This is sample {sample_id}. ')
    
    gt_frames, pred_frames = [], []
    for i in range(ground_truth.shape[1]):
        gt_i = ground_truth[sample_id, i, 0, ...]
        gt_frames.append(list(gt_i))
        
        pred_i = prediction[sample_id, i, 0, ...]
        pred_frames.append(list(pred_i))
    #plot_N(gt_frames)            
    #plot_N(pred_frames)
    clip = ImageSequenceClip(list(gt_frames), fps=4)
    clip.write_gif('test.gif', fps=4)

# %%
import numpy as np
frames = np.random.randint(256, size=[20, 64, 64,1], dtype=np.uint8)  # YOUR DATA HERE
print(frames.shape)
# save it as a gif
from moviepy.editor import ImageSequenceClip
clip = ImageSequenceClip(list(frames), fps=20)
clip.write_gif('test.gif', fps=20)
# Out:
# (20, 64, 64, 1)
# 1
# MoviePy - Building file test.gif with imageio.

# %%
from IPython.display import display, Image
Image('test.gif')
